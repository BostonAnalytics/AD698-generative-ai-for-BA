# %% [raw]
# ---
# title: "AD698 - Applied Generative AI"
# subtitle: "M06 Lab2"
# categories: ['M06:', 'Lab']
# description: "Hands-on lab for Module 6 focused on M06 Lab2."
# ---

# %% [markdown]
# # M06 Lab02
#
# ## Lab Notebook Pattern
#
# When you build this lab out, use a lightweight structure:
#
# 1. Setup
# 2. Core task blocks
# 3. Validation output after each block
# 4. Short interpretation
#
# ## Lab Validation Standard
#
# Students should show intermediate evidence, not only final outputs. Typical checks include traces, sample outputs, small comparison tables, or one short failure analysis note.
