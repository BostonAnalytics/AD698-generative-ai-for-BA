# %% [raw]
# ---
# title: "AD698 - Applied Generative AI"
# subtitle: "AI-Powered Business Dashboards"
# number-sections: true
# date: "2024-11-21"
# date-modified: today
# date-format: long
# engine: jupyter
# bibliography: ../references.bib
# categories: ['M08:', 'Neural Networks', 'Deep Learning', 'Lecture Notes']
# description: "Lecture notes for Module 8 covering AI-Powered Business Dashboards."
# ---
